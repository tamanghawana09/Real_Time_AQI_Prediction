# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('Data_sets/aqi_hourly_dataset.xlsx')

# %%
df.head()
# Out:
#                  DATE  Precipitation  Temperature  Relative Humidity  PM 2.5  \
# 0 2020-09-17 03:00:00            0.0         22.1               84.5    28.9
# 1 2020-09-17 04:00:00            0.0         22.8               80.7    27.5
# 2 2020-09-17 05:00:00            0.0         24.1               74.9    25.5
# 3 2020-09-17 06:00:00            0.0         25.5               70.9    21.3
# 4 2020-09-17 07:00:00            0.0         25.5               69.6    23.6
#
#    O3
# 0   4
# 1   4
# 2   4
# 3   6
# 4   7

# %%
df.shape
# Out:
# (30033, 6)

# %%
df.isnull().sum()
# Out:
# DATE                   0
# Precipitation         44
# Temperature          186
# Relative Humidity    191
# PM 2.5               479
# O3                     0
# dtype: int64

# %%
df.fillna(df.select_dtypes(exclude=['category','object']).mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# DATE                 0
# Precipitation        0
# Temperature          0
# Relative Humidity    0
# PM 2.5               0
# O3                   0
# dtype: int64

# %% [raw]
# The Air Quality Index (AQI) is a measure used to communicate how polluted the air currently is or how polluted it is forecast to become. The AQI scale typically ranges from 0 to 500, and it is divided into categories that indicate different levels of health concern. Here's a general breakdown of the AQI categories:
# Good (0-50):
#
# Air quality is considered good, and the air is generally clean and clear.
# This range indicates little or no health risk from air pollution.
# It's a great time for outdoor activities as air quality poses minimal concern.
# Moderate (51-100):
#
# Air quality is acceptable, but there may be a slight health concern for sensitive individuals.
# People with respirator or heart conditions, children, and older adults may experience minor health effects if exposed for prolonged periods.
# Unhealthy for Sensitive Groups (101-150):
#
# Sensitive groups, such as individuals with respiratory or heart conditions, children, and older adults, may experience health effects.
# The general public is less likely to be affected unless they are part of a sensitive group or engage in strenuous outdoor activities.
# Unhealthy (151-200):
#
# Everyone may begin to experience health effects, with sensitive groups experiencing more serious effects.
# People may notice difficulty in breathing and increased respiratory discomfort, especially during outdoor activities.
# Very Unhealthy (201-300):
#
# Health alerts are issued as everyone may experience more serious health effects.
# Sensitive groups and the general public are at risk of respiratory and cardiovascular issues, and outdoor activities are strongly discouraged.
# Hazardous (301-500):
#
# Health warnings of emergency conditions as the entire population is likely to be affected.
# Severe respiratory and cardiovascular effects are expected, and prolonged exposure can be life-threatening.
# Outdoor activities should be avoided, and staying indoors with air purification may be necessary.
# AQI values above 500 are extremely rare but signify conditions where air quality is beyond hazardous, posing an immediate threat to life.
#
# Understanding these categories helps individuals and communities make informed decisions about outdoor activities and take necessary precautions to protect health during periods of poor air quality.

# %% [raw]
# Certainly! The Air Quality Index (AQI) for PM 2.5 (Particulate Matter with a diameter of 2.5 micrometers or less) also has specific thresholds and corresponding AQI values defined by the U.S. Environmental Protection Agency (EPA). Here’s how the AQI is calculated for PM 2.5:
#
# AQI Calculation for PM 2.5
# For PM 2.5, the EPA defines the following breakpoints:
#
# 0.0 to 12.0 µg/m³:
#
# I_low: 0.0 µg/m³
# I_high: 12.0 µg/m³
# AQI_low: 0
# AQI_high: 50
# 12.1 to 35.4 µg/m³:
#
# I_low: 12.1 µg/m³
# I_high: 35.4 µg/m³
# AQI_low: 51
# AQI_high: 100
# 35.5 to 55.4 µg/m³:
#
# I_low: 35.5 µg/m³
# I_high: 55.4 µg/m³
# AQI_low: 101
# AQI_high: 150
# 55.5 to 150.4 µg/m³:
#
# I_low: 55.5 µg/m³
# I_high: 150.4 µg/m³
# AQI_low: 151
# AQI_high: 200
# 150.5 to 250.4 µg/m³:
#
# I_low: 150.5 µg/m³
# I_high: 250.4 µg/m³
# AQI_low: 201
# AQI_high: 300
# 250.5 to 500.4 µg/m³:
#
# I_low: 250.5 µg/m³
# I_high: 500.4 µg/m³
# AQI_low: 301
# AQI_high: 500
#
#
# Explanation:
# calculate_aqi_pm25 Function: This function takes a concentration value of PM 2.5 (concentration) in µg/m³ as input and calculates the corresponding AQI based on the defined thresholds and AQI values.
# Conditional Statements: Similar to the AQI calculation for Ozone, the function uses conditional statements (if-elif-else) to determine which range (I_low, I_high) the concentration falls into and assigns the corresponding AQI values (AQI_low, AQI_high).
# Interpolation: It then linearly interpolates the AQI value between AQI_low and AQI_high based on where concentration lies between I_low and I_high.

# %% [raw]
# Yes, these values (I_low, I_high, AQI_low, AQI_high) used in the conditional statements are based on the actual thresholds and corresponding AQI values defined by the U.S. Environmental Protection Agency (EPA) for calculating the Air Quality Index (AQI) for Ozone (O3). Let's break down each part:
#
# Understanding the AQI Calculation for Ozone (O3)
# The EPA provides specific breakpoints for Ozone concentrations and their corresponding AQI values:
#
# 0.0 to 54.0 ppb:
#
# I_low: 0.0 ppb (lower bound of this range)
# I_high: 54.0 ppb (upper bound of this range)
# AQI_low: 0 (corresponding AQI value when concentration is at I_low)
# AQI_high: 50 (corresponding AQI value when concentration is at I_high)
# 54.1 to 70.0 ppb:
#
# I_low: 55.0 ppb
# I_high: 70.0 ppb
# AQI_low: 51
# AQI_high: 100
# 70.1 to 85.0 ppb:
#
# I_low: 71.0 ppb
# I_high: 85.0 ppb
# AQI_low: 101
# AQI_high: 150
# 85.1 to 105.0 ppb:
#
# I_low: 86.0 ppb
# I_high: 105.0 ppb
# AQI_low: 151
# AQI_high: 200
# 105.1 to 200.0 ppb:
#
# I_low: 106.0 ppb
# I_high: 200.0 ppb
# AQI_low: 201
# AQI_high: 300
# 200.1 to 400.0 ppb:
#
# I_low: 201.0 ppb
# I_high: 400.0 ppb
# AQI_low: 301
# AQI_high: 500
# Explanation of the Code
# The Python code snippet you provided uses these exact thresholds (I_low, I_high) and AQI values (AQI_low, AQI_high) to compute the AQI for Ozone (O3) based on its concentration (concentration). Here's how it works:
#
# Conditional Statements: The if-elif-else structure checks the value of concentration against each threshold.
# Assignment: Depending on which range concentration falls into, it assigns appropriate values to I_low, I_high, AQI_low, and AQI_high.
# Interpolation: For concentrations within a specific range, it linearly interpolates the AQI value between AQI_low and AQI_high based on where concentration lies between I_low and I_high.
# If concentration falls outside the defined ranges (above 400.0 ppb), the function returns 500, as AQI values above 500 are not typically used due to the severe health impacts associated with such high pollutant concentrations.
#
# Conclusion
# The values (I_low, I_high, AQI_low, AQI_high) used in your code snippet are indeed based on standardized thresholds and AQI values defined by environmental agencies such as the EPA. They are not assumptions but rather precise values used in the calculation of the Air Quality Index for Ozone, ensuring that the computed AQI reflects the potential health risks associated with varying levels of Ozone pollution in the atmosphere.

# %%
# Calculate AQI for PM 2.5
def calculate_aqi_pm25(concentration):
    if concentration <= 12.0:
        I_low, I_high, AQI_low, AQI_high = 0.0, 12.0, 0, 50
    elif concentration <= 35.4:
        I_low, I_high, AQI_low, AQI_high = 12.1, 35.4, 51, 100
    elif concentration <= 55.4:
        I_low, I_high, AQI_low, AQI_high = 35.5, 55.4, 101, 150
    elif concentration <= 150.4:
        I_low, I_high, AQI_low, AQI_high = 55.5, 150.4, 151, 200
    elif concentration <= 250.4:
        I_low, I_high, AQI_low, AQI_high = 150.5, 250.4, 201, 300
    elif concentration <= 500.4:
        I_low, I_high, AQI_low, AQI_high = 250.5, 500.4, 301, 500
    else:
        return 500  # AQI values above 500 are not common
    
    aqi_pm25 = ((concentration - I_low) * (AQI_high - AQI_low)) / (I_high - I_low) + AQI_low
    return round(aqi_pm25)

# Calculate AQI for O3
def calculate_aqi_o3(concentration):
    if concentration <= 54:
        I_low, I_high, AQI_low, AQI_high = 0.0, 54.0, 0, 50
    elif concentration <= 70:
        I_low, I_high, AQI_low, AQI_high = 55.0, 70.0, 51, 100
    elif concentration <= 85:
        I_low, I_high, AQI_low, AQI_high = 71.0, 85.0, 101, 150
    elif concentration <= 105:
        I_low, I_high, AQI_low, AQI_high = 86.0, 105.0, 151, 200
    elif concentration <= 200:
        I_low, I_high, AQI_low, AQI_high = 106.0, 200.0, 201, 300
    elif concentration <= 400:
        I_low, I_high, AQI_low, AQI_high = 201.0, 400.0, 301, 500
    else:
        return 500  # AQI values above 500 are not common
    
    aqi_o3 = ((concentration - I_low) * (AQI_high - AQI_low)) / (I_high - I_low) + AQI_low
    return round(aqi_o3)

# Function to classify AQI
def classify_aqi(aqi):
    if aqi <= 50:
        return 'Good'
    elif aqi <= 100:
        return 'Moderate'
    elif aqi <= 150:
        return 'Unhealthy for Sensitive Groups'
    elif aqi <= 200:
        return 'Unhealthy'
    elif aqi <= 300:
        return 'Very Unhealthy'
    else:
        return 'Hazardous'

# Calculate AQI and classify into categories for PM 2.5
df['AQI_PM2.5'] = df['PM 2.5'].apply(calculate_aqi_pm25)
df['AQI_Category_PM2.5'] = df['AQI_PM2.5'].apply(classify_aqi)

# Calculate AQI and classify into categories for O3
df['AQI_O3'] = df['O3'].apply(calculate_aqi_o3)
df['AQI_Category_O3'] = df['AQI_O3'].apply(classify_aqi)

# %%
df.head()
# Out:
#                  DATE  Precipitation  Temperature  Relative Humidity  PM 2.5  \
# 0 2020-09-17 03:00:00            0.0         22.1               84.5    28.9
# 1 2020-09-17 04:00:00            0.0         22.8               80.7    27.5
# 2 2020-09-17 05:00:00            0.0         24.1               74.9    25.5
# 3 2020-09-17 06:00:00            0.0         25.5               70.9    21.3
# 4 2020-09-17 07:00:00            0.0         25.5               69.6    23.6
#
#    O3  AQI_PM2.5 AQI_Category_PM2.5  AQI_O3 AQI_Category_O3
# 0   4         86           Moderate       4            Good
# 1   4         83           Moderate       4            Good
# 2   4         79           Moderate       4            Good
# 3   6         70           Moderate       6            Good
# 4   7         75           Moderate       6            Good

# %%
# Calculate AQI and classify into categories for PM 2.5
df['AQI_PM2.5'] = df['PM 2.5'].apply(calculate_aqi_pm25)
df['AQI_Category_PM2.5'] = df['AQI_PM2.5'].apply(classify_aqi)

# Calculate AQI and classify into categories for O3
df['AQI_O3'] = df['O3'].apply(calculate_aqi_o3)
df['AQI_Category_O3'] = df['AQI_O3'].apply(classify_aqi)

# Determine the overall AQI (maximum of PM 2.5 and O3 AQI)
df['Overall_AQI'] = df[['AQI_PM2.5', 'AQI_O3']].max(axis=1)

# Classify overall AQI into categories
df['Overall_AQI_Category'] = df['Overall_AQI'].apply(classify_aqi)

# %%
df.head()
# Out:
#                  DATE  Precipitation  Temperature  Relative Humidity  PM 2.5  \
# 0 2020-09-17 03:00:00            0.0         22.1               84.5    28.9
# 1 2020-09-17 04:00:00            0.0         22.8               80.7    27.5
# 2 2020-09-17 05:00:00            0.0         24.1               74.9    25.5
# 3 2020-09-17 06:00:00            0.0         25.5               70.9    21.3
# 4 2020-09-17 07:00:00            0.0         25.5               69.6    23.6
#
#    O3  AQI_PM2.5 AQI_Category_PM2.5  AQI_O3 AQI_Category_O3  Overall_AQI  \
# 0   4         86           Moderate       4            Good           86
# 1   4         83           Moderate       4            Good           83
# 2   4         79           Moderate       4            Good           79
# 3   6         70           Moderate       6            Good           70
# 4   7         75           Moderate       6            Good           75
#
#   Overall_AQI_Category
# 0             Moderate
# ...

# %%
df['Overall_AQI_Category'].value_counts()
# Out:
# Overall_AQI_Category
# Moderate                          10685
# Unhealthy                         10292
# Unhealthy for Sensitive Groups     6032
# Good                               2322
# Very Unhealthy                      560
# Hazardous                           142
# Name: count, dtype: int64

# %%
df.to_csv('Data_sets/filtered_data.csv',index=False)

# %%
# Load the CSV file
file_path = 'Data_sets/filtered_data.csv'  # Update the file path as needed
data = pd.read_csv(file_path)

# Display the first few rows
data.head()
# Out:
#                   DATE  Precipitation  Temperature  Relative Humidity  PM 2.5  \
# 0  2020-09-17 03:00:00            0.0         22.1               84.5    28.9
# 1  2020-09-17 04:00:00            0.0         22.8               80.7    27.5
# 2  2020-09-17 05:00:00            0.0         24.1               74.9    25.5
# 3  2020-09-17 06:00:00            0.0         25.5               70.9    21.3
# 4  2020-09-17 07:00:00            0.0         25.5               69.6    23.6
#
#    O3  AQI_PM2.5 AQI_Category_PM2.5  AQI_O3 AQI_Category_O3  Overall_AQI  \
# 0   4         86           Moderate       4            Good           86
# 1   4         83           Moderate       4            Good           83
# 2   4         79           Moderate       4            Good           79
# 3   6         70           Moderate       6            Good           70
# 4   7         75           Moderate       6            Good           75
#
#   Overall_AQI_Category
# 0             Moderate
# ...

# %%
data.isnull().sum()
# Out:
# DATE                    0
# Precipitation           0
# Temperature             0
# Relative Humidity       0
# PM 2.5                  0
# O3                      0
# AQI_PM2.5               0
# AQI_Category_PM2.5      0
# AQI_O3                  0
# AQI_Category_O3         0
# Overall_AQI             0
# Overall_AQI_Category    0
# dtype: int64

# %%
data.value_counts()
# Out:
# DATE                 Precipitation  Temperature  Relative Humidity  PM 2.5  O3  AQI_PM2.5  AQI_Category_PM2.5              AQI_O3  AQI_Category_O3  Overall_AQI  Overall_AQI_Category
# 2020-09-17 03:00:00  0.0            22.1         84.5               28.9    4   86         Moderate                        4       Good             86           Moderate                          1
# 2023-01-06 17:00:00  0.0            17.5         63.2               46.5    13  128        Unhealthy for Sensitive Groups  12      Good             128          Unhealthy for Sensitive Groups    1
# 2023-01-07 05:00:00  0.0            10.9         99.8               112.2   32  180        Unhealthy                       30      Good             180          Unhealthy                         1
# 2023-01-07 04:00:00  0.0            11.2         99.1               109.5   36  179        Unhealthy                       33      Good             179          Unhealthy                         1
# ...

# %%
# Convert the DATE column to datetime type if it's not already
data['DATE'] = pd.to_datetime(data['DATE'])

# Extract date and time components
data['year'] = data['DATE'].dt.year
data['month'] = data['DATE'].dt.month
data['day'] = data['DATE'].dt.day
data['hour'] = data['DATE'].dt.hour

# Drop the original DATE column if not needed
# For time series forecasting, we might want to keep it as the index
data.set_index('DATE', inplace=True)

# %%
data.head()
# Out:
#                      Precipitation  Temperature  Relative Humidity  PM 2.5  \
# DATE
# 2020-09-17 03:00:00            0.0         22.1               84.5    28.9
# 2020-09-17 04:00:00            0.0         22.8               80.7    27.5
# 2020-09-17 05:00:00            0.0         24.1               74.9    25.5
# 2020-09-17 06:00:00            0.0         25.5               70.9    21.3
# 2020-09-17 07:00:00            0.0         25.5               69.6    23.6
#
#                      O3  AQI_PM2.5 AQI_Category_PM2.5  AQI_O3 AQI_Category_O3  \
# DATE
# 2020-09-17 03:00:00   4         86           Moderate       4            Good
# 2020-09-17 04:00:00   4         83           Moderate       4            Good
# 2020-09-17 05:00:00   4         79           Moderate       4            Good
# 2020-09-17 06:00:00   6         70           Moderate       6            Good
# 2020-09-17 07:00:00   7         75           Moderate       6            Good
#
# ...

# %%
df['Overall_AQI_Category'].value_counts()
# Out:
# Overall_AQI_Category
# Moderate                          10685
# Unhealthy                         10292
# Unhealthy for Sensitive Groups     6032
# Good                               2322
# Very Unhealthy                      560
# Hazardous                           142
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the distribution of Overall AQI values
plt.figure(figsize=(10, 6))
sns.histplot(data['Overall_AQI'], bins=30, kde=True)
plt.title('Distribution of Overall AQI Values')
plt.xlabel('Overall AQI')
plt.ylabel('Frequency')
plt.show()

# Plot Overall AQI over time
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['Overall_AQI'])
plt.title('Overall AQI Over Time')
plt.xlabel('Time')
plt.ylabel('Overall AQI')
plt.show()

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import joblib



# Features and target variables
X_regression = data[['Precipitation', 'Temperature', 'Relative Humidity', 'PM 2.5', 'O3', 'day', 'hour', 'month', 'year']]
y_regression = data['Overall_AQI']

# Split data into training and testing sets
X_train_regression, X_test_regression, y_train_regression, y_test_regression = train_test_split(X_regression, y_regression, test_size=0.2, random_state=42)

# Initialize the regression model (Random Forest Regressor)
model_regression = RandomForestRegressor(random_state=42)

# Train the model
model_regression.fit(X_train_regression, y_train_regression)

# Save the model
joblib.dump(model_regression, r'F:\Real_time_AQI Prediction\ML_Model\regression_model.pkl')

# Optionally, you can evaluate the model using metrics like R-squared, MSE, RMSE, etc.
# Out:
# ['F:\\Real_time_AQI Prediction\\ML_Model\\regression_model.pkl']

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder
import joblib

# Features and target variables for classification
X_classification = data[['Precipitation', 'Temperature', 'Relative Humidity', 'PM 2.5', 'O3', 'day', 'hour', 'month', 'year']]
y_classification = data['Overall_AQI_Category']

# Encode categorical target variable
le = LabelEncoder()
y_classification_encoded = le.fit_transform(y_classification)

# Split data into training and testing sets
X_train_classification, X_test_classification, y_train_classification, y_test_classification = train_test_split(X_classification, y_classification_encoded, test_size=0.2, random_state=42)

# Initialize and train the classification model
model_classification = RandomForestClassifier(random_state=42)
model_classification.fit(X_train_classification, y_train_classification)

# Save the model
joblib.dump(model_classification, r'F:\Real_time_AQI Prediction\ML_Model\classification_model.pkl')

# Optionally, you can evaluate the classification model using metrics like accuracy, confusion matrix, classification report, etc.
# Out:
# ['F:\\Real_time_AQI Prediction\\ML_Model\\classification_model.pkl']

# %%
# data_preparation_eda.py
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Sample Data Preparation
data = pd.read_csv('Data_sets/filtered_data.csv')

# %%
data.head()
# Out:
#                   DATE  Precipitation  Temperature  Relative Humidity  PM 2.5  \
# 0  2020-09-17 03:00:00            0.0         22.1               84.5    28.9
# 1  2020-09-17 04:00:00            0.0         22.8               80.7    27.5
# 2  2020-09-17 05:00:00            0.0         24.1               74.9    25.5
# 3  2020-09-17 06:00:00            0.0         25.5               70.9    21.3
# 4  2020-09-17 07:00:00            0.0         25.5               69.6    23.6
#
#    O3  AQI_PM2.5 AQI_Category_PM2.5  AQI_O3 AQI_Category_O3  Overall_AQI  \
# 0   4         86           Moderate       4            Good           86
# 1   4         83           Moderate       4            Good           83
# 2   4         79           Moderate       4            Good           79
# 3   6         70           Moderate       6            Good           70
# 4   7         75           Moderate       6            Good           75
#
#   Overall_AQI_Category
# 0             Moderate
# ...

# %%
# data_preparation.py
import pandas as pd

# Load the data
data = pd.read_csv('Data_sets/filtered_data.csv')

# Drop the specified columns
columns_to_drop = [
    'AQI_PM2.5', 'AQI_Category_PM2.5', 'AQI_O3', 'AQI_Category_O3',
    'Precipitation', 'Temperature', 'Relative Humidity'
]
data_cleaned = data.drop(columns=columns_to_drop)

# Save the cleaned data for further use
data_cleaned.to_csv('Data_sets/cleaned_data.csv', index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load your data (adjust path as necessary)
data_cleaned = pd.read_csv('Data_sets/cleaned_data.csv')

# %%
data_cleaned.head()
# Out:
#                   DATE  PM 2.5  O3  Overall_AQI Overall_AQI_Category
# 0  2020-09-17 03:00:00    28.9   4           86             Moderate
# 1  2020-09-17 04:00:00    27.5   4           83             Moderate
# 2  2020-09-17 05:00:00    25.5   4           79             Moderate
# 3  2020-09-17 06:00:00    21.3   6           70             Moderate
# 4  2020-09-17 07:00:00    23.6   7           75             Moderate

# %%
data_cleaned.columns
# Out:
# Index(['DATE', 'PM 2.5', 'O3', 'Overall_AQI', 'Overall_AQI_Category'], dtype='object')

# %%
data_cleaned['Overall_AQI_Category'].value_counts()
# Out:
# Overall_AQI_Category
# Moderate                          10685
# Unhealthy                         10292
# Unhealthy for Sensitive Groups     6032
# Good                               2322
# Very Unhealthy                      560
# Hazardous                           142
# Name: count, dtype: int64

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# Load and prepare data (replace this with your actual data loading process)
data_df = pd.read_csv('Data_sets/cleaned_data.csv')
data_df['DATE'] = pd.to_datetime(data_df['DATE'])
data_df.set_index('DATE', inplace=True)
data_df = data_df.sort_index()

# Prepare data for ARIMA
ts = data_df['Overall_AQI']

# Plot the time series
ts.plot(figsize=(12, 6))
plt.title('Time Series of Overall AQI')
plt.xlabel('Date')
plt.ylabel('Overall AQI')
plt.show()

# Fit ARIMA model
model = ARIMA(ts, order=(5, 1, 0))
model_fit = model.fit()

# Forecast the next 24 hours
forecast = model_fit.forecast(steps=24)

# Create a date range for the future period
future_dates = pd.date_range(start=ts.index[-1] + pd.Timedelta(hours=1), periods=24, freq='H')

# Create a DataFrame for the forecast
forecast_df = pd.DataFrame({'DATE': future_dates, 'Forecast': forecast})

# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(ts, label='Historical Data')
plt.plot(forecast_df['DATE'], forecast_df['Forecast'], color='red', linestyle='--', label='Forecast')
plt.title('24-Hour Forecast of Overall AQI')
plt.xlabel('Date')
plt.ylabel('Overall AQI')
plt.legend()
plt.show()

# Print forecast results
print(forecast_df)
# Out:
# C:\Users\thoma\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\thoma\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\thoma\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\thoma\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
# ...

# %%
import pickle
# Save the model to a file
with open('ML_Model/arima_model.pkl', 'wb') as f:
    pickle.dump(model_fit, f)

# %%
import pandas as pd
import pickle
from datetime import datetime
import matplotlib.pyplot as plt

# Load the saved ARIMA model
with open('Real_time_AQI Prediction/arima_model.pkl', 'rb') as f:
    model_fit = pickle.load(f)

# Forecast the next 24 hours from the current date and time
forecast_steps = 24
forecast = model_fit.forecast(steps=forecast_steps)

# Get current date and time
current_time = datetime.now()

# Create a date range starting from the current time
future_dates = pd.date_range(start=current_time, periods=forecast_steps + 1, freq='H')[1:]

# Create a DataFrame for the forecast
forecast_df = pd.DataFrame({'DATE': future_dates, 'Forecast': forecast})

# Plot the results
plt.figure(figsize=(12, 6))
ts = pd.read_csv('/content/drive/MyDrive/Real_time_AQI Prediction/Data_sets/cleaned_data.csv', index_col='DATE', parse_dates=True)['Overall_AQI']  # Reload historical data for plotting
plt.plot(ts, label='Historical Data')
plt.plot(forecast_df['DATE'], forecast_df['Forecast'], color='red', linestyle='--', label='Forecast')
plt.title('24-Hour Forecast of Overall AQI')
plt.xlabel('Date')
plt.ylabel('Overall AQI')
plt.legend()
plt.show()

# Print forecast results
print(forecast_df)
